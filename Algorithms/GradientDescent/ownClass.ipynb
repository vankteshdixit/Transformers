# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([59.77859912])

# %%
lr.intercept_
# Out:
# np.float64(1.6720742222071205)

# %%
m = 59.77

# %%
class GDRegression:

    def __init__(self, learning_rate, epoches):
        self.m = 59.77
        self.b = -120
        self.lr = learning_rate
        self.epoches = epoches

    def fit(self, X, y):
        for  i in range(self.epoches):
            loss_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)

            print(loss_slope,self.b)

        print(self.b)

# %%
gd = GDRegression(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -24334.550936404616 -95.66544906359539
# -19467.640749123693 -76.1978083144717
# -15574.112599298958 -60.623695715172744
# -12459.290079439164 -48.16440563573358
# -9967.432063551332 -38.196973572182245
# -7973.945650841064 -30.22302792134118
# -6379.156520672852 -23.843871400668327
# -5103.32521653828 -18.740546184130046
# -4082.6601732306253 -14.657886010899421
# -3266.1281385845 -11.39175787231492
# -2612.9025108675996 -8.77885536144732
# -2090.32200869408 -6.68853335275324
# -1672.2576069552645 -5.016275745797975
# -1337.806085564211 -3.678469660233764
# -1070.244868451369 -2.608224791782395
# -856.1958947610951 -1.7520288970213
# -684.9567158088762 -1.0670721812124238
# -547.9653726471009 -0.5191068085653228
# -438.3722981176806 -0.08073451044764213
# -350.6978384941446 0.26996332804650247
# -280.55827079531576 0.5505215988418182
# -224.4466166362525 0.7749682154780706
# -179.55729330900203 0.9545255087870727
# -143.64583464720167 1.0981713434342744
# -114.91666771776131 1.2130880111520357
# -91.93333417420911 1.3050213453262447
# -73.54666733936713 1.378568012665612
# -58.83733387149395 1.437405346537106
# -47.06986709719504 1.484475213634301
# -37.65589367775597 1.522131107312057
# -30.12471494220486 1.5522558222542617
# -24.099771953763973 1.5763555942080256
# -19.279817563011097 1.5956354117710367
# -15.423854050408789 1.6110592658214455
# -12.339083240326957 1.6233983490617725
# -9.87126659226162 1.633269615654034
# -7.897013273809282 1.6411666289278433
# -6.317610619047617 1.647484239546891
# -5.0540884952378775 1.6525383280421289
# -4.0432707961904235 1.6565815988383192
# -3.234616636952339 1.6598162154752716
# -2.5876933095619137 1.6624039087848335
